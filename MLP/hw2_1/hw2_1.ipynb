# %%
Name = 'Parsa Ghezelbash'
StudentID = 401110437

# %%
# Feel free to import any other libraries and modules.
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader, Subset
from torch import nn

# %% [markdown]
# # Part One: Optimization Algorithms
# ## 1. Gradient Descent
# The Gradient Descent (GD) algorithm finds the minimum of a given
# function by taking small steps along the function's gradient:
#
# >$\Theta \leftarrow \Theta_0$
#
# >**while** stop condition not met **do**
#
# >$~~~~$$\Theta \leftarrow \Theta - \alpha \nabla_\Theta f(\Theta)$
#
# >**end while**
#
# where $f$ is the function to minimize, $\nabla_\Theta f(\Theta)$
# denotes $f$'s gradient at $\Theta$ and $\alpha$ is the learning rate.
#
# **Task1:** Implement the GD algorithm as a function:
#
#   \begin{equation}
#       \Theta_{opt} = \text{GD}(f, \Theta_0, \alpha, \rho)
#   \end{equation}
# where $f$ is a function returning the cost and its gradient with respect to parameter vector $\Theta$, $\Theta_0$ is the initial value, and $\alpha$
# is the learning rate. You can assume that $\alpha$. remains constant during the optimization. $\rho$ is stop condition. \\
# Then, use the GD algorithm to find the optimum of the [Rosenbrock function](https://en.wikipedia.org/wiki/Rosenbrock_function) (Consider $a=1, b=100$).
#  \\
# Also, plot the values found by GD at subsequent iterations.
#
# ## 2. Newton's Method
# Newton's method is an iterative optimization algorithm used to find the minimum of a function.
# The basic update step in Newton's method is given by:
#
# \begin{equation}
# \Theta = \Theta - H^{-1} \cdot \nabla f(\Theta)
# \end{equation}
#
#
# Where  $ H $ is the Hessian matrix of the function at $ \Theta $, and $ H^{-1} $ is the inverse of the Hessian matrix, used to adjust the step size and direction more accurately than just using the gradient alone (as done in gradient descent).
#
# #### Line Search
# Sometimes, Newton's method may take too large of a step, which can lead to divergence. To prevent this, a simple **line search** is used. This reduces the step size $ \alpha $ if the function value doesn't improve after the step.
#
# Steps:
# 1. Compute the gradient and Hessian matrix at the current point.
# 2. Calculate the step direction by multiplying the inverse of the Hessian with the gradient.
# 3. Update the point by subtracting the step from the current point.
# 4. If the function value doesn't improve, reduce the step size $ \alpha $.
# 5. Repeat until the gradient becomes sufficiently small (close to zero), indicating convergence.
#
#
#
# **Task2:** Implement Newton's method and compare it with the gradient descent. You will also need to implement a line search alogithm, e.g. (https://en.wikipedia.org/wiki/Backtracking_line_search) and make sure that the Newton's direction is indeed one along which the function is minimized.

# %%
def rosenbrock(x):
    """Returns the value and gradient of Rosenbrock's function at x: 2d vector"""
    val = (1 - x[0])**2 + 100 * (x[1] - x[0]**2)**2
    dv_dx0 = -2 * (1 - x[0]) - 4 * 100 * (x[1] - x[0]**2) * x[0]
    dv_dx1 = 2 * 100 * (x[1] - x[0]**2)
    grad = np.array([dv_dx0, dv_dx1])

    return val, grad

def rosenbrock_hessian(x):
    """Returns the value, gradient and hessian of Rosenbrock's function at x: 2d vector"""
    val, grad = rosenbrock(x)

    # Hessian matrix components
    d2v_dx0x0 = 2 - 4 * 100 * (x[1] - x[0]**2) + 8 * 100 * x[0]**2
    d2v_dx0x1 = -4 * 100 * x[0]
    d2v_dx1x0 = -4 * 100 * x[0]
    d2v_dx1x1 = 2 * 100

    # Hessian matrix
    hessian = np.array([[d2v_dx0x0, d2v_dx0x1],
                [d2v_dx1x0, d2v_dx1x1]])

    return val, grad, hessian


def GD(f, theta0, alpha, stop_tolerance=1e-10, max_steps=1000000):
    """Runs gradient descent algorithm on f.

    Args:
        f: function that when evaluated on a Theta of same dtype and shape as Theta0
            returns a tuple (value, dv_dtheta) with dValuedTheta of the same shape
            as Theta
        theta0: starting point
        alpha: step length
        stop_tolerance: stop iterations when improvement is below this threshold
        max_steps: maximum number of steps
    Returns:
        tuple:
        - theta: optimum theta found by the algorithm
        - history: list of length num_steps containing tuples (theta, (val, dv_dtheta: np.array))

    """
    history = []

    theta = np.array(theta0)

    step = 0
    while step < max_steps:
        history.append([theta.copy(), f(theta)])
        theta -= alpha * f(theta)[1]
        if np.linalg.norm(theta - history[-1][0]) < stop_tolerance:
            break
        step += 1

    history.append([theta.copy(), f(theta)])
    return theta, history

# %%
# Find the optimum of rosenbrock function

X0 = [0.,2.]
Xopt, Xhist = GD(rosenbrock, X0, alpha=1e-3, stop_tolerance=1e-10, max_steps=1e6)

print ("Found optimum at %s in %d steps (true minimum is at [1,1])" % (Xopt, len(Xhist)))

# Plot how the value changes over iterations
values = [item[1][0] for item in Xhist]
iterations = range(len(Xhist))

plt.plot(iterations, values, c='red')
plt.title('values vs iterations GD')
plt.xlabel('iterations')
plt.ylabel('rosenbrock value')
plt.show()
# Out:
# Found optimum at [0.99999989 0.99999978] in 37028 steps (true minimum is at [1,1])

# %%
# Newton's Method
def BacktrackLineSearch(f, x, value, grad, direction, beta=0.55, alpha=0.4, t0 = 1):
    t = t0
    step = 0
    while value + alpha * t * (grad.T @ direction) < f(x + t * direction)[0] and step < 20:
        t *= beta
        step += 1
    return t

def Newton(f, theta0, alpha=1, stop_tolerance=1e-10, max_steps=1000000):
    """Performs Newton's optimization method with a simple line search.

    Args:
        f: function that when evaluated on a Theta of same dtype and shape as Theta0
            returns a tuple (value, gradient, hessian), where gradient and Hessian
            have the same shape as Theta.
        theta0: starting point.
        alpha: step length for backtracking line search (default is 1).
        stop_tolerance: stop iterations when the norm of the gradient is below this threshold.
        max_steps: maximum number of iterations.
    Returns:
        tuple:
        - theta: optimal Theta after convergence or maximum steps.
        - history: list of tuples (theta, value, gradient) containing the optimization path.
    """
    theta = np.array(theta0)
    history = []

    step = 0
    while step < max_steps:
        val, grad, hessian = f(theta)
        history.append([theta.copy(), val, grad])

        direction = - np.linalg.solve(hessian, grad)

        t = BacktrackLineSearch(f, theta, val, grad, direction)

        theta += alpha * t * direction

        if np.linalg.norm(grad) < stop_tolerance:
            break

        step += 1


    val, grad, hessian = f(theta)
    history.append([theta, val, grad])
    return theta, history

# Test Newton's method on the Rosenbrock function
X0 = [0., 2.]  # Initial guess
Xopt, Xhist = Newton(rosenbrock_hessian, X0)

print("Found optimum at %s in %d steps (true minimum is at [1,1])" % (Xopt, len(Xhist)))
# Out:
# Found optimum at [1. 1.] in 17 steps (true minimum is at [1,1])

# %% [markdown]
# # Part two: MLP for MNIST Classification
# In this part, we are going to use `PyTorch`. If you want to become more familiar with it, check this resource: https://www.learnpytorch.io/
#
# #### In this homework, you need to
# - implement SGD optimizer (`./optimizer.py`)
# - implement forward and backward for FCLayer (`layers.py`)
# - implement forward and backward for SigmoidLayer (`layers.py`)
# - implement forward and backward for ReLULayer (`layers.py`)
# - implement forward and backward for DropoutLayer (`layers.py`)
# - implement train and test process (`solver.py`)

# %%
from layers import FCLayer, SigmoidLayer, ReLULayer
from solver import train, test
from optimizer import SGD

# %%
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
# Load MNIST dataset

# Converts PIL image to tensor and scales to [0, 1] and flatten it
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.view(-1)),
])

# Load MNIST dataset with the defined transform
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# One-hot encoding for labels
def decode_label(label, num_classes=10):
    return torch.nn.functional.one_hot(torch.tensor(label), num_classes=num_classes).float()

# Preprocess labels and combine with transformed images
y_train = [decode_label(label) for _, label in train_dataset]
y_test = [decode_label(label) for _, label in test_dataset]

# Convert the data into tensor datasets for training and testing
train_dataset = TensorDataset(torch.stack([img for img, _ in train_dataset]), torch.stack(y_train))
test_dataset = TensorDataset(torch.stack([img for img, _ in test_dataset]), torch.stack(y_test))

# Create data loaders
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
num_epoch = 20

criterion = nn.MSELoss()

# Build MLP with FCLayer and SigmoidLayer you've implemented in layers.py
sigmoidMLP = nn.Sequential(
    FCLayer(784, 128),
    SigmoidLayer(),
    FCLayer(128, 10)
)

# Initialize optimizer you've implemented in optimizer.py
sgd = SGD(params=sigmoidMLP.parameters(), learning_rate=0.01)

# Train the model using train function you've implemented in solver.py
sigmoidMLP = train(sigmoidMLP, criterion, sgd, train_dataloader, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.0771, Average training accuracy: 0.4956
#
# Epoch [1] Average training loss: 0.0556, Average training accuracy: 0.7378
#
# Epoch [2] Average training loss: 0.0506, Average training accuracy: 0.7836
#
# Epoch [3] Average training loss: 0.0482, Average training accuracy: 0.8046
#
# Epoch [4] Average training loss: 0.0466, Average training accuracy: 0.8173
#
# Epoch [5] Average training loss: 0.0456, Average training accuracy: 0.8254
#
# Epoch [6] Average training loss: 0.0448, Average training accuracy: 0.8307
#
# Epoch [7] Average training loss: 0.0442, Average training accuracy: 0.8344
#
# Epoch [8] Average training loss: 0.0437, Average training accuracy: 0.8384
#
# Epoch [9] Average training loss: 0.0432, Average training accuracy: 0.8408
#
# Epoch [10] Average training loss: 0.0429, Average training accuracy: 0.8430
#
# Epoch [11] Average training loss: 0.0426, Average training accuracy: 0.8455
#
# Epoch [12] Average training loss: 0.0423, Average training accuracy: 0.8464
#
# Epoch [13] Average training loss: 0.0420, Average training accuracy: 0.8474
#
# Epoch [14] Average training loss: 0.0418, Average training accuracy: 0.8490
#
# Epoch [15] Average training loss: 0.0415, Average training accuracy: 0.8504
#
# Epoch [16] Average training loss: 0.0413, Average training accuracy: 0.8516
#
# Epoch [17] Average training loss: 0.0411, Average training accuracy: 0.8514
#
# Epoch [18] Average training loss: 0.0409, Average training accuracy: 0.8529
#
# Epoch [19] Average training loss: 0.0407, Average training accuracy: 0.8533

# %%
# Test your model using test function you've implemented in solver.py
test(sigmoidMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.8627.

# %%
# Build MLP with FCLayer and ReLULayer
reluMLP = nn.Sequential(
    FCLayer(784, 128),
    ReLULayer(),
    FCLayer(128, 10)
)

# Initialize optimizer
sgd = SGD(reluMLP.parameters(), learning_rate=0.01)

# Train the model
reluMLP = train(reluMLP, criterion, sgd, train_dataloader, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.0712, Average training accuracy: 0.6373
#
# Epoch [1] Average training loss: 0.0467, Average training accuracy: 0.8231
#
# Epoch [2] Average training loss: 0.0399, Average training accuracy: 0.8589
#
# Epoch [3] Average training loss: 0.0357, Average training accuracy: 0.8765
#
# Epoch [4] Average training loss: 0.0327, Average training accuracy: 0.8875
#
# Epoch [5] Average training loss: 0.0305, Average training accuracy: 0.8953
#
# Epoch [6] Average training loss: 0.0288, Average training accuracy: 0.9011
#
# Epoch [7] Average training loss: 0.0274, Average training accuracy: 0.9060
#
# Epoch [8] Average training loss: 0.0262, Average training accuracy: 0.9102
#
# Epoch [9] Average training loss: 0.0253, Average training accuracy: 0.9131
#
# Epoch [10] Average training loss: 0.0244, Average training accuracy: 0.9162
#
# Epoch [11] Average training loss: 0.0237, Average training accuracy: 0.9185
#
# Epoch [12] Average training loss: 0.0231, Average training accuracy: 0.9205
#
# Epoch [13] Average training loss: 0.0225, Average training accuracy: 0.9227
#
# Epoch [14] Average training loss: 0.0220, Average training accuracy: 0.9248
#
# Epoch [15] Average training loss: 0.0215, Average training accuracy: 0.9263
#
# Epoch [16] Average training loss: 0.0211, Average training accuracy: 0.9279
#
# Epoch [17] Average training loss: 0.0207, Average training accuracy: 0.9289
#
# Epoch [18] Average training loss: 0.0204, Average training accuracy: 0.9298
#
# Epoch [19] Average training loss: 0.0200, Average training accuracy: 0.9309

# %%
# Test the model
test(reluMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.9313.

# %% [markdown]
# ### Overfit the model
# Try to overfit the reluMLP model. You can make the model as complex as you like, use subset of the data for training or any other approach you want.
# Then add **DropoutLayer** to your model in order to reduce overfitting problem.

# %%
#TODO: overfit the reluMLP model
num_epoch = 100
train_subset = DataLoader(Subset(train_dataloader.dataset, range(0, 1000)), batch_size=32, shuffle=True)

reluMLP = nn.Sequential(
    FCLayer(784, 512),
    ReLULayer(),
    FCLayer(512, 256),
    ReLULayer(),
    FCLayer(256, 128),
    ReLULayer(),
    FCLayer(128, 10)
)

# Initialize optimizer
sgd = SGD(reluMLP.parameters(), learning_rate=0.01)

# Train the model
reluMLP = train(reluMLP, criterion, sgd, train_subset, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.1282, Average training accuracy: 0.1387
#
# Epoch [1] Average training loss: 0.0974, Average training accuracy: 0.1787
#
# Epoch [2] Average training loss: 0.0909, Average training accuracy: 0.2441
#
# Epoch [3] Average training loss: 0.0858, Average training accuracy: 0.3145
#
# Epoch [4] Average training loss: 0.0816, Average training accuracy: 0.4053
#
# Epoch [5] Average training loss: 0.0783, Average training accuracy: 0.4746
#
# Epoch [6] Average training loss: 0.0749, Average training accuracy: 0.5273
#
# Epoch [7] Average training loss: 0.0724, Average training accuracy: 0.5615
#
# Epoch [8] Average training loss: 0.0699, Average training accuracy: 0.6025
#
# Epoch [9] Average training loss: 0.0679, Average training accuracy: 0.6201
#
# Epoch [10] Average training loss: 0.0657, Average training accuracy: 0.6348
#
# Epoch [11] Average training loss: 0.0640, Average training accuracy: 0.6523
#
# Epoch [12] Average training loss: 0.0624, Average training accuracy: 0.6777
#
# Epoch [13] Average training loss: 0.0613, Average training accuracy: 0.6934
#
# Epoch [14] Average training loss: 0.0599, Average training accuracy: 0.7090
#
# Epoch [15] Average training loss: 0.0586, Average training accuracy: 0.7256
#
# Epoch [16] Average training loss: 0.0568, Average training accuracy: 0.7520
#
# Epoch [17] Average training loss: 0.0563, Average training accuracy: 0.7480
#
# Epoch [18] Average training loss: 0.0549, Average training accuracy: 0.7607
#
# Epoch [19] Average training loss: 0.0543, Average training accuracy: 0.7627
#
# Epoch [20] Average training loss: 0.0531, Average training accuracy: 0.7686
#
# Epoch [21] Average training loss: 0.0520, Average training accuracy: 0.7793
#
# Epoch [22] Average training loss: 0.0518, Average training accuracy: 0.7773
#
# Epoch [23] Average training loss: 0.0505, Average training accuracy: 0.7910
#
# Epoch [24] Average training loss: 0.0492, Average training accuracy: 0.8057
#
# Epoch [25] Average training loss: 0.0492, Average training accuracy: 0.8066
#
# Epoch [26] Average training loss: 0.0481, Average training accuracy: 0.8213
#
# Epoch [27] Average training loss: 0.0472, Average training accuracy: 0.8232
#
# Epoch [28] Average training loss: 0.0470, Average training accuracy: 0.8262
#
# Epoch [29] Average training loss: 0.0462, Average training accuracy: 0.8271
#
# Epoch [30] Average training loss: 0.0461, Average training accuracy: 0.8242
#
# Epoch [31] Average training loss: 0.0449, Average training accuracy: 0.8408
#
# Epoch [32] Average training loss: 0.0443, Average training accuracy: 0.8369
#
# Epoch [33] Average training loss: 0.0438, Average training accuracy: 0.8447
#
# Epoch [34] Average training loss: 0.0428, Average training accuracy: 0.8477
#
# Epoch [35] Average training loss: 0.0432, Average training accuracy: 0.8438
#
# Epoch [36] Average training loss: 0.0422, Average training accuracy: 0.8535
#
# Epoch [37] Average training loss: 0.0421, Average training accuracy: 0.8516
#
# Epoch [38] Average training loss: 0.0418, Average training accuracy: 0.8525
#
# Epoch [39] Average training loss: 0.0408, Average training accuracy: 0.8604
#
# Epoch [40] Average training loss: 0.0400, Average training accuracy: 0.8613
#
# Epoch [41] Average training loss: 0.0404, Average training accuracy: 0.8574
#
# Epoch [42] Average training loss: 0.0402, Average training accuracy: 0.8594
#
# Epoch [43] Average training loss: 0.0393, Average training accuracy: 0.8643
#
# Epoch [44] Average training loss: 0.0388, Average training accuracy: 0.8721
#
# Epoch [45] Average training loss: 0.0385, Average training accuracy: 0.8701
#
# Epoch [46] Average training loss: 0.0381, Average training accuracy: 0.8730
#
# Epoch [47] Average training loss: 0.0376, Average training accuracy: 0.8721
#
# Epoch [48] Average training loss: 0.0378, Average training accuracy: 0.8691
#
# Epoch [49] Average training loss: 0.0367, Average training accuracy: 0.8799
#
# Epoch [50] Average training loss: 0.0368, Average training accuracy: 0.8838
#
# Epoch [51] Average training loss: 0.0366, Average training accuracy: 0.8789
#
# Epoch [52] Average training loss: 0.0360, Average training accuracy: 0.8818
#
# Epoch [53] Average training loss: 0.0356, Average training accuracy: 0.8877
#
# Epoch [54] Average training loss: 0.0353, Average training accuracy: 0.8877
#
# Epoch [55] Average training loss: 0.0349, Average training accuracy: 0.8926
#
# Epoch [56] Average training loss: 0.0349, Average training accuracy: 0.8916
#
# Epoch [57] Average training loss: 0.0349, Average training accuracy: 0.8887
#
# Epoch [58] Average training loss: 0.0342, Average training accuracy: 0.8955
#
# Epoch [59] Average training loss: 0.0343, Average training accuracy: 0.8936
#
# Epoch [60] Average training loss: 0.0334, Average training accuracy: 0.9043
#
# Epoch [61] Average training loss: 0.0334, Average training accuracy: 0.9033
#
# Epoch [62] Average training loss: 0.0329, Average training accuracy: 0.9053
#
# Epoch [63] Average training loss: 0.0328, Average training accuracy: 0.9053
#
# Epoch [64] Average training loss: 0.0327, Average training accuracy: 0.9072
#
# Epoch [65] Average training loss: 0.0322, Average training accuracy: 0.9111
#
# Epoch [66] Average training loss: 0.0323, Average training accuracy: 0.9082
#
# Epoch [67] Average training loss: 0.0322, Average training accuracy: 0.9053
#
# Epoch [68] Average training loss: 0.0316, Average training accuracy: 0.9150
#
# Epoch [69] Average training loss: 0.0316, Average training accuracy: 0.9141
#
# Epoch [70] Average training loss: 0.0311, Average training accuracy: 0.9150
#
# Epoch [71] Average training loss: 0.0310, Average training accuracy: 0.9170
#
# Epoch [72] Average training loss: 0.0306, Average training accuracy: 0.9209
#
# Epoch [73] Average training loss: 0.0306, Average training accuracy: 0.9219
#
# Epoch [74] Average training loss: 0.0309, Average training accuracy: 0.9092
#
# Epoch [75] Average training loss: 0.0301, Average training accuracy: 0.9229
#
# Epoch [76] Average training loss: 0.0297, Average training accuracy: 0.9258
#
# Epoch [77] Average training loss: 0.0297, Average training accuracy: 0.9229
#
# Epoch [78] Average training loss: 0.0296, Average training accuracy: 0.9229
#
# Epoch [79] Average training loss: 0.0291, Average training accuracy: 0.9199
#
# Epoch [80] Average training loss: 0.0291, Average training accuracy: 0.9268
#
# Epoch [81] Average training loss: 0.0287, Average training accuracy: 0.9307
#
# Epoch [82] Average training loss: 0.0290, Average training accuracy: 0.9277
#
# Epoch [83] Average training loss: 0.0283, Average training accuracy: 0.9336
#
# Epoch [84] Average training loss: 0.0282, Average training accuracy: 0.9307
#
# Epoch [85] Average training loss: 0.0283, Average training accuracy: 0.9287
#
# Epoch [86] Average training loss: 0.0281, Average training accuracy: 0.9307
#
# Epoch [87] Average training loss: 0.0278, Average training accuracy: 0.9316
#
# Epoch [88] Average training loss: 0.0277, Average training accuracy: 0.9297
#
# Epoch [89] Average training loss: 0.0275, Average training accuracy: 0.9316
#
# Epoch [90] Average training loss: 0.0270, Average training accuracy: 0.9326
#
# Epoch [91] Average training loss: 0.0270, Average training accuracy: 0.9336
#
# Epoch [92] Average training loss: 0.0271, Average training accuracy: 0.9316
#
# Epoch [93] Average training loss: 0.0269, Average training accuracy: 0.9336
#
# Epoch [94] Average training loss: 0.0266, Average training accuracy: 0.9355
#
# Epoch [95] Average training loss: 0.0264, Average training accuracy: 0.9336
#
# Epoch [96] Average training loss: 0.0262, Average training accuracy: 0.9385
#
# Epoch [97] Average training loss: 0.0265, Average training accuracy: 0.9346
#
# Epoch [98] Average training loss: 0.0259, Average training accuracy: 0.9385
#
# Epoch [99] Average training loss: 0.0257, Average training accuracy: 0.9375

# %%
# Test the model
test(reluMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.8372.

# %%
from layers import DropoutLayer

#TODO: add DropoutLayer to your model
reluMLP = nn.Sequential(
    FCLayer(784, 512),
    ReLULayer(),
    DropoutLayer(dropout_rate=0.1),
    FCLayer(512, 256),
    ReLULayer(),
    DropoutLayer(dropout_rate=0.1),
    FCLayer(256, 128),
    ReLULayer(),
    DropoutLayer(dropout_rate=0.1),
    FCLayer(128, 10)
)

# Initialize optimizer
sgd = SGD(reluMLP.parameters(), learning_rate=0.01)

# Train the model
reluMLP = train(reluMLP, criterion, sgd, train_subset, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.1287, Average training accuracy: 0.1055
#
# Epoch [1] Average training loss: 0.1115, Average training accuracy: 0.1523
#
# Epoch [2] Average training loss: 0.1025, Average training accuracy: 0.2002
#
# Epoch [3] Average training loss: 0.0990, Average training accuracy: 0.2246
#
# Epoch [4] Average training loss: 0.0956, Average training accuracy: 0.2539
#
# Epoch [5] Average training loss: 0.0920, Average training accuracy: 0.2920
#
# Epoch [6] Average training loss: 0.0880, Average training accuracy: 0.3281
#
# Epoch [7] Average training loss: 0.0876, Average training accuracy: 0.3516
#
# Epoch [8] Average training loss: 0.0856, Average training accuracy: 0.3643
#
# Epoch [9] Average training loss: 0.0819, Average training accuracy: 0.4092
#
# Epoch [10] Average training loss: 0.0809, Average training accuracy: 0.4248
#
# Epoch [11] Average training loss: 0.0814, Average training accuracy: 0.4150
#
# Epoch [12] Average training loss: 0.0785, Average training accuracy: 0.4502
#
# Epoch [13] Average training loss: 0.0767, Average training accuracy: 0.4834
#
# Epoch [14] Average training loss: 0.0766, Average training accuracy: 0.4912
#
# Epoch [15] Average training loss: 0.0751, Average training accuracy: 0.5078
#
# Epoch [16] Average training loss: 0.0747, Average training accuracy: 0.5010
#
# Epoch [17] Average training loss: 0.0720, Average training accuracy: 0.5410
#
# Epoch [18] Average training loss: 0.0716, Average training accuracy: 0.5381
#
# Epoch [19] Average training loss: 0.0708, Average training accuracy: 0.5537
#
# Epoch [20] Average training loss: 0.0700, Average training accuracy: 0.5781
#
# Epoch [21] Average training loss: 0.0694, Average training accuracy: 0.5859
#
# Epoch [22] Average training loss: 0.0684, Average training accuracy: 0.5957
#
# Epoch [23] Average training loss: 0.0671, Average training accuracy: 0.5986
#
# Epoch [24] Average training loss: 0.0655, Average training accuracy: 0.6523
#
# Epoch [25] Average training loss: 0.0662, Average training accuracy: 0.6416
#
# Epoch [26] Average training loss: 0.0658, Average training accuracy: 0.6328
#
# Epoch [27] Average training loss: 0.0658, Average training accuracy: 0.6172
#
# Epoch [28] Average training loss: 0.0648, Average training accuracy: 0.6445
#
# Epoch [29] Average training loss: 0.0632, Average training accuracy: 0.6611
#
# Epoch [30] Average training loss: 0.0622, Average training accuracy: 0.6885
#
# Epoch [31] Average training loss: 0.0623, Average training accuracy: 0.6807
#
# Epoch [32] Average training loss: 0.0626, Average training accuracy: 0.6680
#
# Epoch [33] Average training loss: 0.0615, Average training accuracy: 0.6787
#
# Epoch [34] Average training loss: 0.0617, Average training accuracy: 0.6514
#
# Epoch [35] Average training loss: 0.0607, Average training accuracy: 0.6924
#
# Epoch [36] Average training loss: 0.0594, Average training accuracy: 0.7031
#
# Epoch [37] Average training loss: 0.0589, Average training accuracy: 0.7148
#
# Epoch [38] Average training loss: 0.0587, Average training accuracy: 0.7100
#
# Epoch [39] Average training loss: 0.0574, Average training accuracy: 0.7246
#
# Epoch [40] Average training loss: 0.0576, Average training accuracy: 0.7275
#
# Epoch [41] Average training loss: 0.0571, Average training accuracy: 0.7383
#
# Epoch [42] Average training loss: 0.0557, Average training accuracy: 0.7471
#
# Epoch [43] Average training loss: 0.0563, Average training accuracy: 0.7236
#
# Epoch [44] Average training loss: 0.0568, Average training accuracy: 0.7217
#
# Epoch [45] Average training loss: 0.0553, Average training accuracy: 0.7412
#
# Epoch [46] Average training loss: 0.0552, Average training accuracy: 0.7451
#
# Epoch [47] Average training loss: 0.0557, Average training accuracy: 0.7373
#
# Epoch [48] Average training loss: 0.0545, Average training accuracy: 0.7402
#
# Epoch [49] Average training loss: 0.0546, Average training accuracy: 0.7539
#
# Epoch [50] Average training loss: 0.0541, Average training accuracy: 0.7588
#
# Epoch [51] Average training loss: 0.0532, Average training accuracy: 0.7646
#
# Epoch [52] Average training loss: 0.0533, Average training accuracy: 0.7520
#
# Epoch [53] Average training loss: 0.0533, Average training accuracy: 0.7607
#
# Epoch [54] Average training loss: 0.0519, Average training accuracy: 0.7666
#
# Epoch [55] Average training loss: 0.0519, Average training accuracy: 0.7637
#
# Epoch [56] Average training loss: 0.0527, Average training accuracy: 0.7578
#
# Epoch [57] Average training loss: 0.0522, Average training accuracy: 0.7686
#
# Epoch [58] Average training loss: 0.0517, Average training accuracy: 0.7773
#
# Epoch [59] Average training loss: 0.0510, Average training accuracy: 0.7930
#
# Epoch [60] Average training loss: 0.0506, Average training accuracy: 0.7822
#
# Epoch [61] Average training loss: 0.0501, Average training accuracy: 0.7910
#
# Epoch [62] Average training loss: 0.0492, Average training accuracy: 0.8057
#
# Epoch [63] Average training loss: 0.0498, Average training accuracy: 0.8008
#
# Epoch [64] Average training loss: 0.0502, Average training accuracy: 0.7871
#
# Epoch [65] Average training loss: 0.0490, Average training accuracy: 0.8027
#
# Epoch [66] Average training loss: 0.0490, Average training accuracy: 0.7930
#
# Epoch [67] Average training loss: 0.0486, Average training accuracy: 0.8076
#
# Epoch [68] Average training loss: 0.0483, Average training accuracy: 0.8096
#
# Epoch [69] Average training loss: 0.0478, Average training accuracy: 0.8086
#
# Epoch [70] Average training loss: 0.0476, Average training accuracy: 0.8027
#
# Epoch [71] Average training loss: 0.0480, Average training accuracy: 0.8066
#
# Epoch [72] Average training loss: 0.0467, Average training accuracy: 0.8291
#
# Epoch [73] Average training loss: 0.0468, Average training accuracy: 0.8252
#
# Epoch [74] Average training loss: 0.0469, Average training accuracy: 0.8145
#
# Epoch [75] Average training loss: 0.0463, Average training accuracy: 0.8252
#
# Epoch [76] Average training loss: 0.0459, Average training accuracy: 0.8145
#
# Epoch [77] Average training loss: 0.0462, Average training accuracy: 0.8232
#
# Epoch [78] Average training loss: 0.0457, Average training accuracy: 0.8379
#
# Epoch [79] Average training loss: 0.0462, Average training accuracy: 0.8232
#
# Epoch [80] Average training loss: 0.0459, Average training accuracy: 0.8174
#
# Epoch [81] Average training loss: 0.0444, Average training accuracy: 0.8369
#
# Epoch [82] Average training loss: 0.0446, Average training accuracy: 0.8438
#
# Epoch [83] Average training loss: 0.0446, Average training accuracy: 0.8281
#
# Epoch [84] Average training loss: 0.0441, Average training accuracy: 0.8486
#
# Epoch [85] Average training loss: 0.0447, Average training accuracy: 0.8252
#
# Epoch [86] Average training loss: 0.0440, Average training accuracy: 0.8252
#
# Epoch [87] Average training loss: 0.0445, Average training accuracy: 0.8447
#
# Epoch [88] Average training loss: 0.0435, Average training accuracy: 0.8350
#
# Epoch [89] Average training loss: 0.0439, Average training accuracy: 0.8408
#
# Epoch [90] Average training loss: 0.0433, Average training accuracy: 0.8398
#
# Epoch [91] Average training loss: 0.0430, Average training accuracy: 0.8633
#
# Epoch [92] Average training loss: 0.0424, Average training accuracy: 0.8457
#
# Epoch [93] Average training loss: 0.0423, Average training accuracy: 0.8535
#
# Epoch [94] Average training loss: 0.0417, Average training accuracy: 0.8535
#
# Epoch [95] Average training loss: 0.0412, Average training accuracy: 0.8643
#
# Epoch [96] Average training loss: 0.0425, Average training accuracy: 0.8613
#
# Epoch [97] Average training loss: 0.0425, Average training accuracy: 0.8535
#
# Epoch [98] Average training loss: 0.0425, Average training accuracy: 0.8320
#
# Epoch [99] Average training loss: 0.0414, Average training accuracy: 0.8779

# %%
# Test the model
test(reluMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.8265.
